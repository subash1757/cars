# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
Data = pd.read_csv("Cars.csv")

# %%
Data
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %% [markdown]
# # Information of the data

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           8128 non-null   object
#  1   year           8128 non-null   int64
#  2   selling_price  8128 non-null   int64
#  3   km_driven      8128 non-null   int64
#  4   fuel           8128 non-null   object
#  5   seller_type    8128 non-null   object
#  6   transmission   8128 non-null   object
#  7   owner          8128 non-null   object
#  8   mileage        7907 non-null   object
#  9   engine         7907 non-null   object
#  10  max_power      7913 non-null   object
#  11  torque         7906 non-null   object
#  12  seats          7907 non-null   float64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 825.6+ KB

# %%
Data.describe()
# Out:
#               year  selling_price     km_driven        seats
# count  8128.000000   8.128000e+03  8.128000e+03  7907.000000
# mean   2013.804011   6.382718e+05  6.981951e+04     5.416719
# std       4.044249   8.062534e+05  5.655055e+04     0.959588
# min    1983.000000   2.999900e+04  1.000000e+00     2.000000
# 25%    2011.000000   2.549990e+05  3.500000e+04     5.000000
# 50%    2015.000000   4.500000e+05  6.000000e+04     5.000000
# 75%    2017.000000   6.750000e+05  9.800000e+04     5.000000
# max    2020.000000   1.000000e+07  2.360457e+06    14.000000

# %% [markdown]
# ## Count vehicle produced  for each year

# %%
Data["year"].value_counts()
# Out:
# 2017    1018
# 2016     859
# 2018     807
# 2015     776
# 2013     670
# 2012     651
# 2014     621
# 2011     592
# 2019     583
# 2010     394
# 2009     246
# 2008     214
# 2007     183
# 2006     124
# 2005      97
# 2020      74
# 2004      62
# 2003      49
# 2002      27
# 2000      22
# 1999      18
# 1997      11
# 2001      10
# 1998      10
# 1996       3
# 1994       3
# 1995       2
# 1983       1
# 1991       1
# Name: year, dtype: int64

# %% [markdown]
# ## Count of vehicle produced for each year in bar plot

# %%
Data["year"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Count of fuel type

# %%
Data["fuel"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Diesel engine car prize maximum and minimum

# %%
Deisel_list = Data[Data['fuel']=='Diesel']
max_price_Diesel = Deisel_list["selling_price"].max()
name = Deisel_list[Deisel_list["selling_price"]==max_price_Diesel]
maximum_price_Diesel = name[["name","selling_price"]]

maximum_price_Diesel.columns = ["Veichle name","Maximum selling price"]
maximum_price_Diesel
# Out:
#                Veichle name  Maximum selling price
# 2938  BMW X7 xDrive 30d DPE                7200000

# %%
Deisel_list = Data[Data['fuel']=='Diesel']
min_price_Diesel = Deisel_list["selling_price"].min()
name = Deisel_list[Deisel_list["selling_price"]==min_price_Diesel]
minimum_price_Diesel = name[["name","selling_price"]]

minimum_price_Diesel.columns = ["Veichle name","Minimum selling price"]
minimum_price_Diesel
# Out:
#          Veichle name  Minimum selling price
# 5674  Tata Indica DLX                  40000

# %% [markdown]
# ## Petrol engine car prize maximum and minimum

# %%
Petrol_list = Data[Data['fuel']=='Petrol']
max_price_Petrol = Petrol_list["selling_price"].max()
name = Petrol_list[Petrol_list["selling_price"]==max_price_Petrol]
maximum_price_Petrol = name[["name","selling_price"]]

maximum_price_Petrol.columns = ["Veichle name","Maximum selling price"]
maximum_price_Petrol
# Out:
#                       Veichle name  Maximum selling price
# 170  Volvo XC90 T8 Excellence BSIV               10000000

# %%
Petrol_list = Data[Data['fuel']=='Petrol']
min_price_Petrol = Petrol_list["selling_price"].min()
name = Petrol_list[Petrol_list["selling_price"]==min_price_Petrol]
minimum_price_Petrol = name[["name","selling_price"]]

minimum_price_Petrol.columns = ["Veichle name","Minimum selling price"]
minimum_price_Petrol
# Out:
#        Veichle name  Minimum selling price
# 5714  Maruti 800 AC                  29999

# %% [markdown]
# ## LPG engine car prize maximum and minimum

# %%
LPG_list = Data[Data['fuel']=='LPG']
max_price_LPG = LPG_list["selling_price"].max()
name = LPG_list[LPG_list["selling_price"]==max_price_LPG]
maximum_price_LPG = name[["name","selling_price"]]

maximum_price_LPG.columns = ["Veichle name","Maximum selling price"]
maximum_price_LPG
# Out:
#                      Veichle name  Maximum selling price
# 3042  Hyundai i10 Sportz 1.1L LPG                 375000

# %%
LPG_list = Data[Data['fuel']=='LPG']
min_price_LPG = LPG_list["selling_price"].min()
name = LPG_list[LPG_list["selling_price"]==min_price_LPG]
minimum_price_LPG = name[["name","selling_price"]]

minimum_price_LPG.columns = ["Veichle name","Minimum selling price"]
minimum_price_LPG
# Out:
#                                    Veichle name  Minimum selling price
# 6007  Maruti Omni LPG CARGO BSIII W IMMOBILISER                  54000

# %% [markdown]
# ## CNG engine car prize maximum and minimum

# %%
CNG_list = Data[Data['fuel']=='CNG']
max_price_CNG = CNG_list["selling_price"].max()
name = CNG_list[CNG_list["selling_price"]==max_price_CNG]
maximum_price_CNG = name[["name","selling_price"]]

maximum_price_CNG.columns = ["Veichle name","Maximum selling price"]
maximum_price_CNG
# Out:
#                                Veichle name  Maximum selling price
# 5749  Maruti Ertiga VXI CNG Limited Edition                 545000

# %%
CNG_list = Data[Data['fuel']=='CNG']
min_price_CNG = CNG_list["selling_price"].min()
name = CNG_list[CNG_list["selling_price"]==min_price_CNG]
minimum_price_CNG = name[["name","selling_price"]]

minimum_price_CNG.columns = ["Veichle name","Minimum selling price"]
minimum_price_CNG
# Out:
#          Veichle name  Minimum selling price
# 4933  Maruti Omni CNG                  80000

# %% [markdown]
# ## Pei-chart to show the seller_type

# %%
Data["seller_type"].value_counts().plot.pie(autopct="%1.1f%%",explode=(0,0,0.5))
# Out:
# <AxesSubplot:ylabel='seller_type'>

# %% [markdown]
# ## Count of transmission

# %%
Data["transmission"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Finding a distribution between owners and selling price

# %%
plt.figure(figsize=(15,15))
sns.boxplot(x="owner",y="selling_price",data=Data);

# %% [markdown]
# ## Counting transmission based on the years

# %%
plt.figure(figsize=(15,20))
sns.countplot(x="year",hue="transmission",data=Data);
plt.ylabel("transmission");

# %% [markdown]
# ## Ploting year distribution

# %%
sns.distplot(x=Data["year"],bins=20);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## summarized whole dataset

# %%
plt.figure(figsize=(15,15))
sns.pairplot(Data, hue='fuel', size=2.5);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
